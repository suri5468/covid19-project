# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("covid-nationality.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 0           0  2020-02-24T18:00:00   ITA                         101
# 1           1  2020-02-25T18:00:00   ITA                         114
# 2           2  2020-02-26T18:00:00   ITA                         128
# 3           3  2020-02-27T18:00:00   ITA                         248
# 4           4  2020-02-28T18:00:00   ITA                         345
#
#    intensive_care  total_hospitalized  home_quarantine  total_confirmed_cases  \
# 0              26                 127               94                    221
# 1              35                 150              162                    311
# 2              36                 164              221                    385
# 3              56                 304              284                    588
# 4              64                 409              412                    821
#
#    variation_total_confirmed  new_confirmed_cases  recovered  deaths  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
data.tail()
# Out:
#     Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 65          65  2020-04-29T17:00:00   ITA                       19210
# 66          66  2020-04-30T17:00:00   ITA                       18149
# 67          67  2020-05-01T17:00:00   ITA                       17569
# 68          68  2020-05-02T17:00:00   ITA                       17357
# 69          69  2020-05-03T17:00:00   ITA                       17242
#
#     intensive_care  total_hospitalized  home_quarantine  \
# 65            1795               21005            83652
# 66            1694               19843            81708
# 67            1578               19147            81796
# 68            1539               18896            81808
# 69            1501               18743            81436
#
#     total_confirmed_cases  variation_total_confirmed  new_confirmed_cases  \
# 65                 104657                       -548                 2086
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0  hospitalized_with_symptoms  intensive_care  \
# count   70.000000                   70.000000       70.000000
# mean    34.500000                17373.142857     2225.128571
# std     20.351085                10475.956363     1330.399743
# min      0.000000                  101.000000       26.000000
# 25%     17.250000                 6844.000000     1196.750000
# 50%     34.500000                20522.500000     2325.500000
# 75%     51.750000                27262.750000     3392.250000
# max     69.000000                29010.000000     4068.000000
#
#        total_hospitalized  home_quarantine  total_confirmed_cases  \
# count           70.000000        70.000000              70.000000
# mean         19598.285714     41387.885714           60986.157143
# std          11743.460668     32774.474616           42510.504183
# min            127.000000        94.000000             221.000000
# 25%           8040.750000      5327.250000           13368.000000
# ...

# %%
data.mean()
# Out:
# Unnamed: 0                    3.450000e+01
# hospitalized_with_symptoms    1.737314e+04
# intensive_care                2.225129e+03
# total_hospitalized            1.959829e+04
# home_quarantine               4.138789e+04
# total_confirmed_cases         6.098616e+04
# variation_total_confirmed     1.427971e+03
# new_confirmed_cases           3.010129e+03
# recovered                     2.362346e+04
# deaths                        1.209519e+04
# total_cases                   9.670480e+04
# swabs_made                    6.873203e+05
# casi_testati                  1.195250e+06
# dtype: float64

# %%
data.isnull().sum()# use sum() to get the numeric values or else it will show the boolean values
# Out:
# Unnamed: 0                     0
# date                           0
# state                          0
# hospitalized_with_symptoms     0
# intensive_care                 0
# total_hospitalized             0
# home_quarantine                0
# total_confirmed_cases          0
# variation_total_confirmed      0
# new_confirmed_cases            0
# recovered                      0
# deaths                         0
# total_cases                    0
# swabs_made                     0
# casi_testati                  55
# note_it                       52
# note_en                       52
# dtype: int64

# %% [markdown]
# # Relating the variable with scatterplot

# %%
sns.relplot(x="total_cases",y="recovered", data=data)

# %%
sns.relplot(x="total_cases",y="deaths", data=data)

# %%
sns.relplot(x="total_cases",y="total_confirmed_cases", data=data)

# %%
sns.relplot(x="hospitalized_with_symptoms",y="total_confirmed_cases", data=data)

# %%
sns.relplot(x="total_confirmed_cases",y="hospitalized_with_symptoms",hue="recovered" ,data=data)

# %%
sns.pairplot(data,size=5)
# Out:
# c:\python38\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
sns.relplot(x="total_cases",y="home_quarantine", kind= "line", data=data)

# %%
sns.relplot(x="recovered",y="home_quarantine", kind= "line", data=data)

# %%
sns.relplot(x="intensive_care",y="recovered", data=data)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'casi_testati', 'note_it', 'note_en'],
#       dtype='object')

# %%
sns.catplot(x="total_cases",y="recovered", data=data)
